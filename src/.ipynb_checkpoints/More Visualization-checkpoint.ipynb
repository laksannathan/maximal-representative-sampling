# %% [markdown]
# ### This notebook plots missing values and remaining attributes for GESIS and GBS.
# TODO: Code is redundant and can be simplified (currently copy-pasted)

# %%
from pathlib import Path
import os
from PIL import Image 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path = Path(os.getcwd()).parent

gbs = pd.read_csv(os.path.join(path, 'data/gbs_processed.csv'), encoding = "ISO-8859-1", delimiter = ',')
gesis = pd.read_csv(os.path.join(path, 'data/gesis_processed.csv'), encoding = "ISO-8859-1", delimiter = ',')

# %%
gesis.drop(['GESIS-CODE'], axis=1, inplace=True)
gbs.drop(['GBS-CODE'], axis=1, inplace=True)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,12))

sns.heatmap(gbs.iloc[:,0:14].isnull(), cbar=False, ax=axs[0])
sns.heatmap(gbs.iloc[:,14:41].isnull(), cbar=False, ax=axs[1])

plt.tight_layout()
plt.savefig(os.path.join(path, 'tex/fig/gbs_missing.png'))

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,12))

sns.heatmap(gesis.iloc[:,0:14].isnull(), cbar=False, ax=axs[0])
sns.heatmap(gesis.iloc[:,14:41].isnull(), cbar=False, ax=axs[1])

plt.tight_layout()
plt.savefig(os.path.join(path, 'tex/fig/gesis_missing.png'))

# %%
fig = plt.figure(figsize = (10,15))
ax = fig.gca()

gbs[['Schlechter Schlaf', 'Leben genießen',
       'Zu Nichts aufraffen', 'Alles anstrengend',
       'Zufriedenheit Leben', 'Aktiv',
       'Verärgert', 'Wach', 'Ängstlich',
       'Nervoes', 'Druck', 'Optimismus Zukunft']].hist(ax=ax)

plt.savefig(os.path.join(path, 'tex/fig/gbs_hist.png'))
plt.show()
# Out:
# c:\users\laksa\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:3267: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
image_file = Image.open(os.path.join(path, 'tex/fig/gbs_hist.png'))
image_file = image_file.convert('1') # convert image to black and white
image_file.save(os.path.join(path, 'tex/fig/gbs_hist.png'))

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()

gesis[['Schlechter Schlaf', 'Leben genießen',
       'Zu Nichts aufraffen', 'Alles anstrengend',
       'Zufriedenheit Leben', 'Aktiv',
       'Verärgert', 'Wach', 'Ängstlich',
       'Nervoes', 'Druck', 'Optimismus Zukunft']].hist(ax=ax)

plt.savefig(os.path.join(path, 'tex/fig/gesis_hist.png'))
plt.show()

# %%
image_file = Image.open(os.path.join(path, 'tex/fig/gesis_hist.png'))
image_file = image_file.convert('1') # convert image to black and white
image_file.save(os.path.join(path, 'tex/fig/gesis_hist.png'))

# %%
g = sns.jointplot("Wahlabsicht", "Wahlteilnahme", data=gbs, kind="reg",
                  #xlim=(0, 60), ylim=(0, 12), 
                  color="black", height=7)

# %%
gbs.drop(['Gruppe'], axis=1, inplace=True)

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# %%
fig = plt.figure(figsize = (12,12))
ax = fig.gca()

corr = gbs.corr()
sns.heatmap(corr,
            cmap='binary',
            mask=mask,
            square=True,
            linewidths=.5,
            vmin=-0.5, vmax=1,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

plt.tight_layout()
plt.savefig(os.path.join(path, 'tex/fig/gbs_corr.png'))
plt.show()

# %%
fig = plt.figure(figsize = (12,12))
ax = fig.gca()

corr = gesis.corr()
sns.heatmap(corr, 
            cmap='binary',
            mask = mask,
            square=True,
            linewidths=.5,
            vmin=-0.5, vmax=1,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

plt.tight_layout()
plt.savefig(os.path.join(path, 'tex/fig/gesis_corr.png'))
plt.show()
