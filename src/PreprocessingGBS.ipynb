# %% [markdown]
# ### This notebook processes GBS data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

gbs1 = pd.read_csv('data_merged.csv')
gbs2 = pd.read_csv('gbs_bfi_lev.csv')

mapping1 = pd.read_csv('r1.csv', encoding = "ISO-8859-1", delimiter = ';')
mapping2 = pd.read_csv('r2.csv', encoding = "ISO-8859-1", delimiter = ';')
key = 'GBS-CODE'
mapping1 = mapping1.rename(columns={'GBS Code': key})
mapping2 = mapping2.rename(columns={'GBS Code': key})
gbs1 = gbs1.rename(columns={'gbs_code': key})
gbs2 = gbs2.rename(columns={'GBS-Code': key})

df = pd.merge(gbs1, gbs2, how='inner', on=key)
df = pd.merge(df, mapping1, how='left', on=key)
df = pd.merge(df, mapping2, how='left', on=key)

attributes1 = ['am01','am02_01','am11','am10','am23','am14','am15','am17','am22','am24','am29','am27']
attributes2 = ['gh03_08','gh08_03','gh04_01','gh05_01','pt04',
               'pt03_01','pt01_02','gh07_01','gh04_01','gh03_10','gh03_07','gh03_13','gh03_11']
attributes3 = ['v2673_1_bfi_bfi1','v2673_1_bfi_bfi2','v2673_1_bfi_bfi3','v2673_1_bfi_bfi4','v2673_1_bfi_bfi5',
               'v2673_1_bfi_bfi6','v2673_1_bfi_bfi7','v2673_1_bfi_bfi8','v2673_1_bfi_bfi9','v2673_1_bfi_bfi10']

attribute_name1 = ['Geschlecht','Geburtsjahr','Geburtsland','Nationalitaet','Familienstand','Hoechster Bildungsabschluss',
                    'Berufliche Ausbildung','Erwerbstaetigkeit','Berufsgruppe','Personen im Haushalt',
                    'Nettoeinkommen Selbst','Nettoeinkommen Haushalt']
attribute_name2 = ['Schlechter Schlaf','Leben genießen','Zu Nichts aufraffen','Alles anstrengend','Wahlteilnahme','Wahlabsicht',
                    'Desinteresse Politiker','Zufriedenheit Leben','Aktiv','Verärgert','Wach','Nervös','Ängstlich']
attribute_name3 = ['Zurueckhaltend','leicht Vertrauen','Faulheit','Entspannt','wenig kuenstlerisches Interesse','Gesellig',
                    'Andere kritisieren','Gruendlich','Nervoes','Phantasievoll']

df = df[[key] + ['Gruppe'] + attributes1 + attributes2 +  attributes3]
df.columns = [key] + ['Gruppe'] + attribute_name1 + attribute_name2 + attribute_name3

df = df.sort_values(by=['GBS-CODE'])

# %%
def merge(arr1, arr2):
    result = []
    for i,j in zip(arr1, arr2):
        if(i != i):
            result.append(j)
        else:
            result.append(i)
    return result

df2 = pd.DataFrame(columns=df.columns)

j = 0
skip = False

for i in range(len(df.Gruppe)-1):
    if(not skip):
        if(df.iloc[i]["GBS-CODE"] == df.iloc[i+1]["GBS-CODE"]):
            df2.loc[j] = merge(df.iloc[i].values, df.iloc[i+1].values)
            j = j+1
            skip = True
        else:
            df2.loc[j] = df.iloc[i].values
            j = j+1
    else:
        skip = False
        
df = df2.copy()
df
# Out:
#       GBS-CODE   Gruppe Geschlecht Geburtsjahr          Geburtsland  \
# 0    GBS+00027  NEGATIV   männlich  1969-03-09          Deutschland
# 1    GBS+00032  POSITIV   weiblich  1949-02-20          Deutschland
# 2    GBS+00071  POSITIV   weiblich  1960-11-04          Deutschland
# 3    GBS+00084  POSITIV   weiblich  1962-05-03          Deutschland
# 4    GBS+00092      NaN   weiblich  1957-03-28          Deutschland
# 5    GBS+00123  POSITIV   weiblich  1963-07-30          Deutschland
# 6    GBS+00135  POSITIV   männlich  1961-02-23          Deutschland
# 7    GBS+00143  NEGATIV   männlich  1947-02-12          Deutschland
# 8    GBS+00155      NaN   weiblich  1961-07-23  sonstige, und zwar:
# 9    GBS+00172  NEGATIV   männlich  1949-01-15          Deutschland
# 10   GBS+00178      NaN   weiblich  1965-12-02          Deutschland
# 11   GBS+00179  NEGATIV   weiblich  1968-12-04          Deutschland
# 12   GBS+00180  POSITIV   weiblich  1961-06-04          Deutschland
# 13   GBS+00183  POSITIV   weiblich  1957-09-18          Deutschland
# 14   GBS+00199      NaN   männlich  1955-10-25          Deutschland
# 15   GBS+00226  NEGATIV   weiblich  1962-06-29          Deutschland
# 16   GBS+00232  POSITIV   männlich  1974-10-27          Deutschland
# 17   GBS+00234  POSITIV   männlich  1958-04-09          Deutschland
# 18   GBS+00242      NaN   männlich  1959-07-19          Deutschland
# 19   GBS+00253  NEGATIV   weiblich  1951-11-15          Deutschland
# 20   GBS+00259      NaN   weiblich  1967-10-27          Deutschland
# 21   GBS+00271  NEGATIV   weiblich  1957-10-21          Deutschland
# 22   GBS+00272  NEGATIV   weiblich  1956-03-15          Deutschland
# 23   GBS-01709      NaN   weiblich  1965-05-30          Deutschland
# 24   GBS-01759  NEGATIV   männlich  1964-04-28          Deutschland
# 25   GBS-01820  POSITIV   männlich  1970-03-05          Deutschland
# 26   GBS-01866      NaN   männlich  1984-02-18          Deutschland
# 27   GBS-01925      NaN   weiblich  1981-01-07          Deutschland
# 28   GBS-02040      NaN   weiblich  1969-08-10          Deutschland
# 29   GBS-02103  POSITIV   weiblich  1995-11-16          Deutschland
# ..         ...      ...        ...         ...                  ...
# 549  GBS-34425      NaN   weiblich  1976-01-15  sonstige, und zwar:
# 550  GBS-34509  POSITIV   weiblich  1985-10-19          Deutschland
# 551  GBS-34514      NaN   weiblich  1983-01-08          Deutschland
# 552  GBS-34516      NaN   weiblich  1996-07-04          Deutschland
# 553  GBS-34518  NEGATIV   weiblich  1987-07-14          Deutschland
# 554  GBS-34633      NaN   männlich  1989-10-11  sonstige, und zwar:
# 555  GBS-34636  POSITIV   weiblich  1989-01-18          Deutschland
# 556  GBS-34669      NaN   weiblich  1991-10-23          Deutschland
# 557  GBS-34701      NaN   männlich  1977-04-11          Deutschland
# 558  GBS-34753  POSITIV   weiblich  1996-02-28          Deutschland
# 559  GBS-34759  POSITIV   weiblich  1987-11-15          Deutschland
# 560  GBS-34866  NEGATIV   männlich  1975-08-07          Deutschland
# 561  GBS-34889      NaN   weiblich  1978-09-14          Deutschland
# 562  GBS-34902      NaN   weiblich  1989-12-15          Deutschland
# 563  GBS-34971  POSITIV   männlich  1967-11-29          Deutschland
# 564  GBS-35109      NaN   männlich  1971-08-29          Deutschland
# 565  GBS-35137      NaN   weiblich  1964-06-08          Deutschland
# 566  GBS-35139  POSITIV   weiblich  1957-03-27          Deutschland
# 567  GBS-35228      NaN   männlich  1967-12-05          Deutschland
# 568  GBS-35230  POSITIV   weiblich  1957-11-18          Deutschland
# 569  GBS-35255      NaN   männlich  1966-08-29          Deutschland
# 570  GBS-35393  POSITIV   männlich  1963-04-12          Deutschland
# 571  GBS-35531      NaN   männlich  1960-04-04  sonstige, und zwar:
# 572  GBS-35794      NaN   männlich  1985-08-29          Deutschland
# 573  GBS-35800      NaN   männlich  1977-04-18          Deutschland
# 574  GBS-35839  POSITIV   weiblich  1962-01-15          Deutschland
# 575  GBS-35943      NaN   männlich  1965-09-12          Deutschland
# 576  GBS-35948  POSITIV   weiblich  1992-07-15          Deutschland
# 577  GBS-35965  NEGATIV   männlich  1966-02-23          Deutschland
# 578  GBS-36088  NEGATIV   weiblich  1983-09-09          Deutschland
#
#      Nationalitaet                                      Familienstand  \
# 0              1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 1              1.0                                              Ledig
# 2              1.0                                         Geschieden
# 3              1.0                                         Geschieden
# 4              1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 5              1.0  Verheiratet und lebe von meinem/meiner Ehepart...
# 6              1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 7              1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 8              2.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 9              1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 10             1.0                                         Geschieden
# 11             1.0                                         Geschieden
# 12             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 13             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 14             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 15             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 16             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 17             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 18             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 19             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 20             1.0                                         Geschieden
# 21             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 22             1.0                                         Geschieden
# 23             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 24             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 25             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 26             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 27             1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 28             1.0                                              Ledig
# 29             1.0                                              Ledig
# ..             ...                                                ...
# 549            2.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 550            1.0                                              Ledig
# 551            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 552            1.0                                              Ledig
# 553            1.0                                              Ledig
# 554            1.0                                              Ledig
# 555            1.0                                              Ledig
# 556            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 557            1.0                                         Geschieden
# 558            1.0                                              Ledig
# 559            1.0                                              Ledig
# 560            1.0                                              Ledig
# 561            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 562            1.0                                              Ledig
# 563            1.0                                         Geschieden
# 564            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 565            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 566            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 567            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 568            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 569            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 570            1.0                                         Geschieden
# 571            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 572            1.0                                              Ledig
# 573            1.0                                              Ledig
# 574            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 575            1.0                                              Ledig
# 576            1.0                                              Ledig
# 577            1.0  Verheiratet und lebe mit meinem/r Ehepartner/-...
# 578            1.0                                              Ledig
#
#                            Hoechster Bildungsabschluss  \
# 0                  Realschulabschluss (Mittlere Reife)
# 1                                   Hochschulabschluss
# 2                  Realschulabschluss (Mittlere Reife)
# 3    Abitur, allgemeine oder fachgebundene Hochschu...
# 4                                   Hochschulabschluss
# 5              Hauptschulabschluss/Volksschulabschluss
# 6                                   Hochschulabschluss
# 7                  Realschulabschluss (Mittlere Reife)
# 8                                   Hochschulabschluss
# 9                  Realschulabschluss (Mittlere Reife)
# 10                 Realschulabschluss (Mittlere Reife)
# 11   Abitur, allgemeine oder fachgebundene Hochschu...
# 12   Fachhochschulreife (Abschluss einer Fachobersc...
# 13   Abitur, allgemeine oder fachgebundene Hochschu...
# 14                 Realschulabschluss (Mittlere Reife)
# 15                 Realschulabschluss (Mittlere Reife)
# 16                 Realschulabschluss (Mittlere Reife)
# 17                 Realschulabschluss (Mittlere Reife)
# 18                                  Hochschulabschluss
# 19                 Realschulabschluss (Mittlere Reife)
# 20                 Realschulabschluss (Mittlere Reife)
# 21                 Realschulabschluss (Mittlere Reife)
# 22   Fachhochschulreife (Abschluss einer Fachobersc...
# 23                 Realschulabschluss (Mittlere Reife)
# 24             Hauptschulabschluss/Volksschulabschluss
# 25                                  Hochschulabschluss
# 26                                  Hochschulabschluss
# 27                                  Hochschulabschluss
# 28                                  Hochschulabschluss
# 29   Abitur, allgemeine oder fachgebundene Hochschu...
# ..                                                 ...
# 549                                 Hochschulabschluss
# 550                                 Hochschulabschluss
# 551                                 Hochschulabschluss
# 552  Abitur, allgemeine oder fachgebundene Hochschu...
# 553  Abitur, allgemeine oder fachgebundene Hochschu...
# 554                                 Hochschulabschluss
# 555                                 Hochschulabschluss
# 556                                 Hochschulabschluss
# 557                                 Hochschulabschluss
# 558  Fachhochschulreife (Abschluss einer Fachobersc...
# 559                                 Hochschulabschluss
# 560                                 Hochschulabschluss
# 561  Abitur, allgemeine oder fachgebundene Hochschu...
# 562  Abitur, allgemeine oder fachgebundene Hochschu...
# 563                                 Hochschulabschluss
# 564            Hauptschulabschluss/Volksschulabschluss
# 565                Realschulabschluss (Mittlere Reife)
# 566            Hauptschulabschluss/Volksschulabschluss
# 567                                 Hochschulabschluss
# 568            Hauptschulabschluss/Volksschulabschluss
# 569                                 Hochschulabschluss
# 570                                 Hochschulabschluss
# 571                                 Hochschulabschluss
# 572                                 Hochschulabschluss
# 573                                 Hochschulabschluss
# 574                Realschulabschluss (Mittlere Reife)
# 575                Realschulabschluss (Mittlere Reife)
# 576  Abitur, allgemeine oder fachgebundene Hochschu...
# 577                                 Hochschulabschluss
# 578                            Anderer Schulabschluss:
#
#                                  Berufliche Ausbildung  Erwerbstaetigkeit  \
# 0    Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 1        Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 2    Beruflich-schulische Ausbildung (Berufsfachsch...                1.0
# 3    Beruflich-schulische Ausbildung (Berufsfachsch...                1.0
# 4    Universitätsabschluss (z. B. Diplom, Magister,...                1.0
# 5    Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 6        Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 7    Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 8    Universitätsabschluss (z. B. Diplom, Magister,...                1.0
# 9    Ausbildung an einer Fach-, Meister-, Techniker...                1.0
# 10   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 11   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 12   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 13   Beruflich-schulische Ausbildung (Berufsfachsch...                1.0
# 14   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 15   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 16   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 17   Beruflich-schulische Ausbildung (Berufsfachsch...                1.0
# 18       Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 19   Ausbildung an einer Fach-, Meister-, Techniker...                1.0
# 20   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 21   Ausbildung an einer Fach-, Meister-, Techniker...                1.0
# 22   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 23   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 24   Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 25         Bachelor an (Fach-)Hochschule abgeschlossen                1.0
# 26         Bachelor an (Fach-)Hochschule abgeschlossen                1.0
# 27       Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 28   Ausbildung an einer Fach-, Meister-, Techniker...                1.0
# 29   Beruflich-schulische Ausbildung (Berufsfachsch...                1.0
# ..                                                 ...                ...
# 549  Universitätsabschluss (z. B. Diplom, Magister,...                1.0
# 550      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 551      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 552  Noch in beruflicher Ausbildung (Berufsvorberei...                1.0
# 553  Beruflich-betriebliche Berufsausbildung (Lehre...                3.0
# 554        Bachelor an (Fach-)Hochschule abgeschlossen                2.0
# 555        Bachelor an (Fach-)Hochschule abgeschlossen                2.0
# 556        Bachelor an (Fach-)Hochschule abgeschlossen                2.0
# 557                                          Promotion                1.0
# 558  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 559  Universitätsabschluss (z. B. Diplom, Magister,...                1.0
# 560      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 561  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 562  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 563      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 564  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 565  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 566  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 567      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 568  Keinen beruflichen Abschluss und bin nicht in ...                1.0
# 569      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 570      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 571  Universitätsabschluss (z. B. Diplom, Magister,...                1.0
# 572      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 573      Fachhochschulabschluss (z. B. Diplom, Master)                2.0
# 574  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 575  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
# 576  Noch in beruflicher Ausbildung (Berufsvorberei...                3.0
# 577      Fachhochschulabschluss (z. B. Diplom, Master)                1.0
# 578  Beruflich-betriebliche Berufsausbildung (Lehre...                1.0
#
#                   ...                                Zurueckhaltend  \
# 0                 ...                      trifft eher nicht zu (2)
# 1                 ...                                weder noch (3)
# 2                 ...                           eher zutreffend (4)
# 3                 ...                           eher zutreffend (4)
# 4                 ...                      trifft eher nicht zu (2)
# 5                 ...                      trifft eher nicht zu (2)
# 6                 ...                                weder noch (3)
# 7                 ...                   trifft voll und ganz zu (5)
# 8                 ...                           eher zutreffend (4)
# 9                 ...                           eher zutreffend (4)
# 10                ...                           eher zutreffend (4)
# 11                ...                                weder noch (3)
# 12                ...                                weder noch (3)
# 13                ...                trifft ueberhaupt nicht zu (1)
# 14                ...                           eher zutreffend (4)
# 15                ...                           eher zutreffend (4)
# 16                ...                      trifft eher nicht zu (2)
# 17                ...                           eher zutreffend (4)
# 578  trifft voll und ganz zu (5)  trifft ueberhaupt nicht zu (1)
#
#                       Phantasievoll
# 0       trifft voll und ganz zu (5)
# 1       trifft voll und ganz zu (5)
# 2               eher zutreffend (4)
# 3                    weder noch (3)
# 4       trifft voll und ganz zu (5)
# 5       trifft voll und ganz zu (5)
# 6    trifft ueberhaupt nicht zu (1)
# 7               eher zutreffend (4)
# 8                    weder noch (3)
# 9                    weder noch (3)
# 10      trifft voll und ganz zu (5)
# 11                   weder noch (3)
# 12              eher zutreffend (4)
# 13                   weder noch (3)
# 14              eher zutreffend (4)
# 15      trifft voll und ganz zu (5)
# 16      trifft voll und ganz zu (5)
# 17                   weder noch (3)
# 18              eher zutreffend (4)
# 19              eher zutreffend (4)
# 20         trifft eher nicht zu (2)
# 21                   weder noch (3)
# 22              eher zutreffend (4)
# 23      trifft voll und ganz zu (5)
# 24                   weder noch (3)
# 25      trifft voll und ganz zu (5)
# 26                   weder noch (3)
# 27              eher zutreffend (4)
# 28      trifft voll und ganz zu (5)
# 29                   weder noch (3)
# ..                              ...
# 549        trifft eher nicht zu (2)
# 550        trifft eher nicht zu (2)
# 551     trifft voll und ganz zu (5)
# 552     trifft voll und ganz zu (5)
# 553             eher zutreffend (4)
# 554     trifft voll und ganz zu (5)
# 555     trifft voll und ganz zu (5)
# 556                  weder noch (3)
# 557        trifft eher nicht zu (2)
# 558     trifft voll und ganz zu (5)
# 559        trifft eher nicht zu (2)
# 560     trifft voll und ganz zu (5)
# 561     trifft voll und ganz zu (5)
# 562                  weder noch (3)
# 563        trifft eher nicht zu (2)
# 564             eher zutreffend (4)
# 565        trifft eher nicht zu (2)
# 566     trifft voll und ganz zu (5)
# 567             eher zutreffend (4)
# 568     trifft voll und ganz zu (5)
# 569             eher zutreffend (4)
# 570             eher zutreffend (4)
# 571                  weder noch (3)
# 572             eher zutreffend (4)
# 573             eher zutreffend (4)
# 574     trifft voll und ganz zu (5)
# 575                  weder noch (3)
# 576        trifft eher nicht zu (2)
# 577     trifft voll und ganz zu (5)
# 578             eher zutreffend (4)
#
# [579 rows x 37 columns]

# %%
rep1 = {
    '5 Trifft voll und ganz zu':5,
    '4 Eher zutreffend':4,
    '3 Weder noch':3,
    '2 Trifft eher nicht zu':2,
    '1 Trifft überhaupt nicht zu':1,
    
    'trifft voll und ganz zu (5)':5,
    'eher zutreffend (4)':4,
    'weder noch (3)':3,     
    'trifft eher nicht zu (2)':2,
    'trifft ueberhaupt nicht zu (1)':1, 
    
    'Unit nonresponse':np.nan,
    'Not in panel':np.nan,
    'Item nonresponse':np.nan,
    'Not reached':np.nan,
    'Ambiguous answer':np.nan,
    'keine Angabe':np.nan,
     
    -1:np.nan,
    -9:np.nan
}
rep2 = {
     True:1,
     False:0,
    'Ja':1,
    'Nein':0,
    'True':1,
    'False':0,
    
    'Ja, ich würde wählen.':1,
    'Weiß ich nicht':0.5,
    'Ich war nicht wahlberechtigt.':0.5,
    'Ich bin nicht wahlberechtigt.':0.5,
    'Ich war nicht wahlberechtigt':0.5,
    'Ja, ich würde wählen.':1,
    'Nein, ich würde nicht wählen.':0,
    
    'Nie':1,
    'Fast nie':2,
    'Manchmal':3,
    'Meistens':4,
    'Fast Immer':4,
    'Fast immer':4,
    'Immer':4,
    
    'Gar nicht':1,
    'Ein bisschen':2,
    'Einigermaßen':3,
    'Äußerst':4,
    'Erheblich':4
}

df = df.replace(rep1)
df = df.replace(rep2)

# %%
di1 = {'männlich': 0, "Männlich": 0, 'weiblich': 1, "Weiblich": 1, '[NA] Keine Angabe':np.nan}
df = df.replace({"Geschlecht": di1})

df['Geburtsjahr'] = df['Geburtsjahr'].astype(str).str[0:4].astype(int)

di3 = {'Türkei':0, 'Österreich': 0, 
       'Item nonresponse': np.nan, 'sonstige, und zwar:': 0, 'Europa':0, 'Deutschland':1, 'Andere':0}
df = df.replace({'Geburtsland': di3})

di4 = {2.0: 0, 2:0}
df = df.replace({'Nationalitaet': di4})

di5 = {'Verheiratet/ Eing. LP zus. lebend':1,
       'Verheiratet und lebe mit meinem/r Ehepartner/-in zusammen': 1, 
       'Geschieden/ Eing. LP aufgehoben': 2,
       'Geschieden': 2,
       'Ledig': 2,
       'In eingetragener Lebenspartnerschaft zusammenlebend (gleichgeschlechtlich)':1,
       'Verheiratet und lebe von meinem/meiner Ehepartner/-in getrennt': 0,
       'Eingetragene Lebenspartnerschaft, getrennt lebend (gleichgeschlechtlich)': 0,
       'Eingetragene/r Lebenspartner/-in verstorben (gleichgeschlechtlich)': 0,
       'Verheiratet/ Eing. LP getrennt lebend': 0,
       'Geschieden/ Eing. LP aufgehoben':2,
       '[NA] Keine Angabe':np.nan,
       'Verwitwet': 0,
       'Verwitwet/ Eing. LP verstorben': 0,
       'Item nonresponse':np.nan}
df = df.replace({'Familienstand': di5})

di6 = {'Abitur, allgemeine oder fachgebundene Hochschulreife (Gymnasium bzw. EOS)': 3,
       'Abitur, allgemeine oder fachgebundene Hochschulreife': 3,
       'Item nonresponse':np.nan, 
       'Anderer Schulabschluss:':np.nan, 
       'Anderer Schulabschluss':np.nan,
       'Fachhochschulreife, Fachoberschule': 3,
       'Realschulabschluss':2,
       'Polytechnische Oberschule DDR, Abschluss 10. Klasse': 2,
       'Fachhochschulreife (Abschluss einer Fachoberschule)': 2,
       'Schüler/-in': np.nan,
       'Hauptschulabschluss':1,
       'Hochschulabschluss':3,
       'Hauptschulabschluss/Volksschulabschluss': 1,
       'Von der Schule abgegangen ohne Hauptschulabschluss':np.nan,
       'Realschulabschluss (Mittlere Reife)': 2,
       'Polytechnische Oberschule DDR, Abschluss 8.oder 9. Klasse': 2,
       'Abschluss Polytechnische Oberschule 10. Klasse (vor 1965: 8. Klasse)': 2}
df = df.replace({'Hoechster Bildungsabschluss': di6})

di7 = {1.0: 51,
       2.0: 52,
       3.0:np.nan,
       4.0:np.nan,
      -1.0:np.nan,
      'Geringfügig erwerbstätig, 400-Euro-Job, Minijob':53,
      'Item nonresponse':np.nan,
      'In einer beruflichen Ausbildung/Lehre':50,
      'In Umschulung':54,
      'Altersteilzeit (nicht mehr am Arbeitsplatz)':54,
      '\'Ein-Euro-Job\' (bei Bezug von Arbeitslosengeld II)':52,
      'Gelegentlich oder unregelmäßig beschäftigt':52,
      'Freiwilliger (Wehr-)Dienst':51,
      'Mutterschafts-, Erziehungsurlaub, Elternzeit oder sonstige Beurlaubung':52,
      'Vollzeiterwerbstätig':51,
      'Nicht erwerbstätig':52,
      'Teilzeiterwerbstätig':53}
#df = df.replace({'Erwerbstaetigkeit': di7})

df['Personen im Haushalt'].value_counts()
di8 = {'Item nonresponse':np.nan,
       '[NA] Keine Angabe':np.nan,
       'eine Person':1,
       '1':1,
       'mehrere Personen, und zwar:':np.nan,
      '5 und mehr':5,
      '4':4,
      '3':3,
      '2':2}
df = df.replace({'Personen im Haushalt': di8})

df['Nettoeinkommen Selbst'].value_counts()
di9 = {'Item nonresponse':np.nan,
        'Missing by filter': np.nan,
       'Angabe verweigert':np.nan,
       'Weiß nicht':np.nan,     
'6000 € und mehr'                     :5000,
'5000 bis unter 6000 €'               :5000,
'4000 bis unter 5000 €'               :4000,
'3200 bis unter 4000 €'               :3200,
'2600 bis unter 3200 €'               :3200,
'2300 bis unter 2600 €'               :2300,
'2000 bis unter 2300 €'               :2000,
'1700 bis unter 2000 €'               :1700,
'1500 bis unter 1700 €'               :1500,
'1300 bis unter 1500 €'               :1300,
'1100 bis unter 1300 €'               :1100,
'900 bis unter 1100 €'                 :900,
'700 bis unter 900 €'                  :700,
'700 € und weniger'                    :0, 
'4 000\t bis unter\t4 500 Euro'       :4000,
'3 750\t bis unter \t4 000 Euro'      :3200,
'6 000\t bis unter \t7 500 Euro'      :5000,
'3 000\t bis unter \t3 250 Euro'      :3200,
'2 000\t bis unter\t2 250 Euro'       :2000,
'4 500\t bis unter\t5 000 Euro'       :4000,
'5000\t bis unter\t5 500 Euro'        :5000,
'2 750\t bis unter \t3 000 Euro'      :2600,
'3 250\t bis unter \t3 500 Euro'      :3200,
'1 750 \t bis unter\t2 000 Euro'      :1700,
'2 250\t bis unter\t2 500 Euro'       :2300,
'5 500\t bis unter\t6 000 Euro'       :5000,
'500 \t bis unter\t800 Euro'           :700,
'2 500 \t bis unter \t2 750 Euro'     :2300,
'7 500 \t bis unter \t10 000 Euro'    :5000,
'3 500\t bis unter \t3 750 Euro'      :3200,
'1 500\t bis unter\t1 750 Euro'       :1500,
'1 250 \t bis unter \t1 500 Euro'     :1300,
'801\t bis unter \t1 000 Euro'         :900,
'10 000\t bis unter\t20 000 Euro'     :5000,
'1 000 \t bis unter \t1 250 Euro'     :1100,
'401 \t bis unter 500 Euro'              :0,
'150 \t bis unter\t400 Euro'             :0,
'unter 150 Euro'                         :0,
'Kein eigenes Einkommen'                 :np.nan,
'kein eigenes Einkommen'                 :np.nan,
'300 bis unter 500 €'                    :0,
'500 bis unter 700 €'                    :700,
'unter 300 €'                            :0,
'5000 € und mehr'                        :5000}
df = df.replace({'Nettoeinkommen Selbst': di9})
df = df.replace({'Nettoeinkommen Haushalt': di9})

di10 = {
'Angestellte(r)':0,
'Missing by filter':np.nan,
'Arbeiter/-in':1,
'Selbstständiger':2,
'Beamter/-in, Richter/-in, Berufssoldat/-in':3,
'Akademiker/-in in freiem Beruf':4,
'Ausbildung':5,
'Selbstständiger Landwirt/-in':6,
'Item nonresponse':7,
'Mithelfende(r) Familienangehörige(r)':8,
'Angestellte(r)':0,
'keine passende Angabe':np.nan,
'Beamter/Beamtin, Richter/-in, Berufssoldat/-in':3,
'Ausbildung':5,
'Selbstständige (im Handel, im Gastgewerbe, im Handwerk, in der Industrie, der Dienstleistung, auch Ich-AG oder Produktionsgenossenschaft des Handwerks (PGH)-Mitglied)':2,
'Akademiker/-in in freiem Beruf (Arzt/Ärztin, Rechtsanwalt/-anwältin, Steuerberater/-in u. Ä.)':4,
'[NA] Keine Angabe':np.nan,
'Arbeiter/-in':1,
'mithelfende(r) Familienangehörige(r)':8,
'Selbstständige(r) Landwirt/-in bzw. Genossenschaftsbauer/-bäuerin':6
}
df = df.replace({'Berufsgruppe': di10})

di11 = {
'Beruflich-betriebliche Berufsausbildung':1,
'Universitätsabschluss':2,
'Kein beruflicher Abschluss, nicht beruflicher Ausbildung':3,
'Ausbildung an Fach-, Meister-, Technikerschule,Berufs- oder Fachakademie':4,
'Fachhochschulabschluss':5,
'Beruflich-schulische Ausbildung':6,
'Student/-in':7,
'Noch in beruflicher Ausbildung':8,
'Ausbildung an Fachschule der DDR':9,
'Schüler/-in an berufsorientiertre Aufbau-, Fachschule o. Ä.':10,
'Item nonresponse':np.nan,
'Missing by filter':np.nan,
'Anderer beruflicher Abschluss':11,

'Beruflich-betriebliche Berufsausbildung (Lehre) abgeschlossen':1,
'Universitätsabschluss (z. B. Diplom, Magister, Staatsexamen, Master)':2,
'Fachhochschulabschluss (z. B. Diplom, Master)':5,
'Noch in beruflicher Ausbildung (Berufsvorbereitungsjahr, Auszubildende/r, Praktikant/-in, Student/-in)':8,
'Ausbildung an einer Fach-, Meister-, Technikerschule, Berufs- oder Fachakademie abgeschlossen':4,
'Bachelor an (Fach-)Hochschule abgeschlossen':5,
'Beruflich-schulische Ausbildung (Berufsfachschule, Handelsschule, Vorbereitungsdienst für den mittleren Dienst in der öffentlichen Verwaltung) abgeschlossen':6,
'Promotion':2,
'Anderer Abschluss, und zwar:':np.nan,
'Keinen beruflichen Abschluss und bin nicht in beruflicher Ausbildung':3,
'Ausbildung an einer Fachschule der DDR abgeschlossen':9,
'[NA] Keine Angabe':np.nan   
}
df = df.replace({'Berufliche Ausbildung': di11})

#df = df.fillna(df.median())
df.head(5)
# Out:
#     GBS-CODE   Gruppe  Geschlecht  Geburtsjahr  Geburtsland  Nationalitaet  \
# 0  GBS+00027  NEGATIV         0.0         1969            1            1.0
# 1  GBS+00032  POSITIV         1.0         1949            1            1.0
# 2  GBS+00071  POSITIV         1.0         1960            1            1.0
# 3  GBS+00084  POSITIV         1.0         1962            1            1.0
# 4  GBS+00092      NaN         1.0         1957            1            1.0
#
#    Familienstand  Hoechster Bildungsabschluss  Berufliche Ausbildung  \
# 0            1.0                          2.0                    1.0
# 1            2.0                          3.0                    5.0
# 2            2.0                          2.0                    6.0
# 3            2.0                          3.0                    6.0
# 4            1.0                          3.0                    2.0
#
#    Erwerbstaetigkeit      ...        Zurueckhaltend  leicht Vertrauen  \
# 0                1.0      ...                   2.0               4.0
# 1                1.0      ...                   3.0               3.0
# 2                1.0      ...                   4.0               4.0
# 3                1.0      ...                   4.0               4.0
# 4                1.0      ...                   2.0               5.0
#
#    Faulheit  Entspannt  wenig kuenstlerisches Interesse  Gesellig  \
# 0       2.0        2.0                              1.0       5.0
# 1       2.0        2.0                              1.0       4.0
# 2       4.0        3.0                              4.0       2.0
# 3       2.0        4.0                              4.0       2.0
# 4       2.0        4.0                              2.0       4.0
#
#    Andere kritisieren  Gruendlich  Nervoes  Phantasievoll
# 0                 4.0         4.0      3.0            5.0
# 1                 2.0         5.0      1.0            5.0
# 2                 2.0         4.0      3.0            4.0
# 3                 3.0         4.0      2.0            3.0
# 4                 2.0         5.0      2.0            5.0
#
# [5 rows x 37 columns]

# %%
#df= df.fillna(df.mean())
df.to_csv('gbs_processed.csv', encoding = "ISO-8859-1", index= False)
df.columns
df['Wahlteilnahme'].value_counts()
#df["Desinteresse Politiker"].value_counts()
# Out:
# 1.0    527
# 0.0     29
# Name: Wahlteilnahme, dtype: int64

# %%
df.iloc[0]
# Out:
# GBS-CODE                           GBS+00027
# Gruppe                               NEGATIV
# Geschlecht                                 0
# Geburtsjahr                             1969
# Geburtsland                                1
# Nationalitaet                              1
# Familienstand                              1
# Hoechster Bildungsabschluss                2
# Berufliche Ausbildung                      1
# Erwerbstaetigkeit                          1
# Berufsgruppe                               3
# Personen im Haushalt                     NaN
# Nettoeinkommen Selbst                   3200
# Nettoeinkommen Haushalt                 3200
# Schlechter Schlaf                          2
# Leben genießen                             2
# Zu Nichts aufraffen                        3
# Alles anstrengend                          2
# Wahlteilnahme                              1
# Wahlabsicht                                5
# Desinteresse Politiker                     2
# Zufriedenheit Leben                        2
# Aktiv                                      3
# Verärgert                                  2
# Wach                                       2
# Nervös                                     2
# Ängstlich                                  4
# Zurueckhaltend                             2
# leicht Vertrauen                           4
# Faulheit                                   2
# Entspannt                                  2
# wenig kuenstlerisches Interesse            1
# Gesellig                                   5
# Andere kritisieren                         4
# Gruendlich                                 4
# Nervoes                                    3
# Phantasievoll                              5
# Name: 0, dtype: object

# %%
df['Berufliche Ausbildung'].value_counts()
# Out:
# 2.0    161
# 1.0    131
# 5.0    115
# 8.0     53
# 4.0     52
# 6.0     35
# 3.0     11
# 9.0      4
# Name: Berufliche Ausbildung, dtype: int64

# %%
df.columns
# Out:
# Index(['GBS-CODE', 'Gruppe', 'Geschlecht', 'Geburtsjahr', 'Geburtsland',
#        'Nationalitaet', 'Familienstand', 'Hoechster Bildungsabschluss',
#        'Berufliche Ausbildung', 'Erwerbstaetigkeit', 'Berufsgruppe',
#        'Personen im Haushalt', 'Nettoeinkommen Selbst',
#        'Nettoeinkommen Haushalt', 'Schlechter Schlaf', 'Leben genießen',
#        'Zu Nichts aufraffen', 'Alles anstrengend', 'Wahlteilnahme',
#        'Wahlabsicht', 'Desinteresse Politiker', 'Zufriedenheit Leben', 'Aktiv',
#        'Verärgert', 'Wach', 'Nervös', 'Ängstlich', 'Zurueckhaltend',
#        'leicht Vertrauen', 'Faulheit', 'Entspannt',
#        'wenig kuenstlerisches Interesse', 'Gesellig', 'Andere kritisieren',
#        'Gruendlich', 'Nervoes', 'Phantasievoll'],
#       dtype='object')
